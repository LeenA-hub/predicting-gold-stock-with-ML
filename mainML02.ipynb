# %%
import yfinance as yf

# %%
gold = yf.Ticker("GC=F")

# %%
gold  = gold.history(period = "max")

# %%
gold
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-08-30 00:00:00-04:00   273.899994   273.899994   273.899994   273.899994
# 2000-08-31 00:00:00-04:00   274.799988   278.299988   274.799988   278.299988
# 2000-09-01 00:00:00-04:00   277.000000   277.000000   277.000000   277.000000
# 2000-09-05 00:00:00-04:00   275.799988   275.799988   275.799988   275.799988
# 2000-09-06 00:00:00-04:00   274.200012   274.200012   274.200012   274.200012
# ...                                ...          ...          ...          ...
# 2024-12-23 00:00:00-05:00  2620.000000  2627.699951  2611.100098  2612.300049
# 2024-12-24 00:00:00-05:00  2613.000000  2620.000000  2609.500000  2620.000000
# 2024-12-26 00:00:00-05:00  2628.500000  2638.800049  2627.899902  2638.800049
# 2024-12-27 00:00:00-05:00  2617.699951  2617.699951  2616.399902  2617.199951
# 2024-12-30 00:00:00-05:00  2636.100098  2640.699951  2632.000000  2633.300049
#
#                            Volume  Dividends  Stock Splits
# Date
# 2000-08-30 00:00:00-04:00       0        0.0           0.0
# 2000-08-31 00:00:00-04:00       0        0.0           0.0
# 2000-09-01 00:00:00-04:00       0        0.0           0.0
# 2000-09-05 00:00:00-04:00       2        0.0           0.0
# 2000-09-06 00:00:00-04:00       0        0.0           0.0
# ...                           ...        ...           ...
# 2024-12-23 00:00:00-05:00     451        0.0           0.0
# 2024-12-24 00:00:00-05:00      35        0.0           0.0
# 2024-12-26 00:00:00-05:00      84        0.0           0.0
# 2024-12-27 00:00:00-05:00      84        0.0           0.0
# 2024-12-30 00:00:00-05:00   13695        0.0           0.0
#
# [6105 rows x 7 columns]

# %%
gold.index
# Out:
# DatetimeIndex(['2000-08-30 00:00:00-04:00', '2000-08-31 00:00:00-04:00',
#                '2000-09-01 00:00:00-04:00', '2000-09-05 00:00:00-04:00',
#                '2000-09-06 00:00:00-04:00', '2000-09-07 00:00:00-04:00',
#                '2000-09-08 00:00:00-04:00', '2000-09-11 00:00:00-04:00',
#                '2000-09-12 00:00:00-04:00', '2000-09-13 00:00:00-04:00',
#                ...
#                '2024-12-16 00:00:00-05:00', '2024-12-17 00:00:00-05:00',
#                '2024-12-18 00:00:00-05:00', '2024-12-19 00:00:00-05:00',
#                '2024-12-20 00:00:00-05:00', '2024-12-23 00:00:00-05:00',
#                '2024-12-24 00:00:00-05:00', '2024-12-26 00:00:00-05:00',
#                '2024-12-27 00:00:00-05:00', '2024-12-30 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=6105, freq=None)

# %%
gold.plot.line(y ="Close", use_index= True)
# Out:
# <Axes: xlabel='Date'>

# %%
del gold["Dividends"]
del gold["Stock Splits"]

# %%
gold["Tomorrow"] = gold["Close"].shift(-1)

# %%
gold["Target"] = (gold["Tomorrow"] > gold["Close"]).astype(int)

# %%
gold
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-08-30 00:00:00-04:00   273.899994   273.899994   273.899994   273.899994
# 2000-08-31 00:00:00-04:00   274.799988   278.299988   274.799988   278.299988
# 2000-09-01 00:00:00-04:00   277.000000   277.000000   277.000000   277.000000
# 2000-09-05 00:00:00-04:00   275.799988   275.799988   275.799988   275.799988
# 2000-09-06 00:00:00-04:00   274.200012   274.200012   274.200012   274.200012
# ...                                ...          ...          ...          ...
# 2024-12-23 00:00:00-05:00  2620.000000  2627.699951  2611.100098  2612.300049
# 2024-12-24 00:00:00-05:00  2613.000000  2620.000000  2609.500000  2620.000000
# 2024-12-26 00:00:00-05:00  2628.500000  2638.800049  2627.899902  2638.800049
# 2024-12-27 00:00:00-05:00  2617.699951  2617.699951  2616.399902  2617.199951
# 2024-12-30 00:00:00-05:00  2636.100098  2640.699951  2632.000000  2633.300049
#
#                            Volume     Tomorrow  Target
# Date
# 2000-08-30 00:00:00-04:00       0   278.299988       1
# 2000-08-31 00:00:00-04:00       0   277.000000       0
# 2000-09-01 00:00:00-04:00       0   275.799988       0
# 2000-09-05 00:00:00-04:00       2   274.200012       0
# 2000-09-06 00:00:00-04:00       0   274.000000       0
# ...                           ...          ...     ...
# 2024-12-23 00:00:00-05:00     451  2620.000000       1
# 2024-12-24 00:00:00-05:00      35  2638.800049       1
# 2024-12-26 00:00:00-05:00      84  2617.199951       0
# 2024-12-27 00:00:00-05:00      84  2633.300049       1
# 2024-12-30 00:00:00-05:00   13695          NaN       0
#
# [6105 rows x 7 columns]

# %%
gold = gold.loc["1990-01-01" :].copy()

# %%
from sklearn.ensemble import RandomForestClassifier 
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
train = gold.iloc[:-100]
test = gold.iloc[-100:]


predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(test["Target"], preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.59        41
#            1       1.00      0.02      0.03        59
#
#     accuracy                           0.42       100
#    macro avg       0.71      0.51      0.31       100
# weighted avg       0.76      0.42      0.26       100

# %%
print(train["Target"].value_counts())
print(test["Target"].value_counts())
# Out:
# Target
# 1    3141
# 0    2864
# Name: count, dtype: int64
# Target
# 1    59
# 0    41
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=1)
X_resampled, y_resampled = smote.fit_resample(train[predictors], train["Target"])

# %%
print(set(train.index) & set(test.index))
# Out:
# set()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(gold, test_size=0.2, random_state=1)

# %%
model = RandomForestClassifier(
    n_estimators=50, 
    max_depth=5, 
    min_samples_split=10, 
    random_state=1
)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, train[predictors], train["Target"], cv=5, scoring="precision")
print(scores.mean())
# Out:
# 0.524072729935939

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(gold, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    2523
# 0    1082
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5093143083630598

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.520111
# 0    0.479889
# Name: count, dtype: float64

# %%
horizons = [ 2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = gold.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}" 
    gold[ratio_column] = gold["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    gold[trend_column] = gold.shift(1).rolling(horizon).sum()["Target"]

    new_predictors += [ratio_column, trend_column]

# %%
gold
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-08-30 00:00:00-04:00   273.899994   273.899994   273.899994   273.899994
# 2000-08-31 00:00:00-04:00   274.799988   278.299988   274.799988   278.299988
# 2000-09-01 00:00:00-04:00   277.000000   277.000000   277.000000   277.000000
# 2000-09-05 00:00:00-04:00   275.799988   275.799988   275.799988   275.799988
# 2000-09-06 00:00:00-04:00   274.200012   274.200012   274.200012   274.200012
# ...                                ...          ...          ...          ...
# 2024-12-23 00:00:00-05:00  2620.000000  2627.699951  2611.100098  2612.300049
# 2024-12-24 00:00:00-05:00  2613.000000  2620.000000  2609.500000  2620.000000
# 2024-12-26 00:00:00-05:00  2628.500000  2638.800049  2627.899902  2638.800049
# 2024-12-27 00:00:00-05:00  2617.699951  2617.699951  2616.399902  2617.199951
# 2024-12-30 00:00:00-05:00  2636.100098  2640.699951  2632.000000  2633.300049
#
#                            Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 2000-08-30 00:00:00-04:00       0   278.299988       1            NaN
# 2000-08-31 00:00:00-04:00       0   277.000000       0       1.007968
# 2000-09-01 00:00:00-04:00       0   275.799988       0       0.997659
# 2000-09-05 00:00:00-04:00       2   274.200012       0       0.997829
# 2000-09-06 00:00:00-04:00       0   274.000000       0       0.997091
# ...                           ...          ...     ...            ...
# 2024-12-23 00:00:00-05:00     451  2620.000000       1       0.996871
# 2024-12-24 00:00:00-05:00      35  2638.800049       1       1.001472
# 2024-12-26 00:00:00-05:00      84  2617.199951       0       1.003575
# 2024-12-27 00:00:00-05:00      84  2633.300049       1       0.995890
# 2024-12-30 00:00:00-05:00   13695          NaN       0       1.003066
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2000-08-30 00:00:00-04:00      NaN            NaN      NaN             NaN
# 2000-08-31 00:00:00-04:00      NaN            NaN      NaN             NaN
# 2000-09-01 00:00:00-04:00      1.0            NaN      NaN             NaN
# 2000-09-05 00:00:00-04:00      0.0            NaN      NaN             NaN
# 2000-09-06 00:00:00-04:00      0.0       0.994055      NaN             NaN
# ...                            ...            ...      ...             ...
# 2024-12-23 00:00:00-05:00      1.0       0.995989      1.0        0.980341
# 2024-12-24 00:00:00-05:00      1.0       1.000787      2.0        0.983330
# 2024-12-26 00:00:00-05:00      2.0       1.007791      3.0        0.990562
# 2024-12-27 00:00:00-05:00      1.0       0.997637      3.0        0.982638
# 2024-12-30 00:00:00-05:00      1.0       1.003422      3.0        0.988830
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2000-08-30 00:00:00-04:00       NaN              NaN        NaN
# 2000-08-31 00:00:00-04:00       NaN              NaN        NaN
# 2000-09-01 00:00:00-04:00       NaN              NaN        NaN
# 2000-09-05 00:00:00-04:00       NaN              NaN        NaN
# 2000-09-06 00:00:00-04:00       NaN              NaN        NaN
# ...                             ...              ...        ...
# 2024-12-23 00:00:00-05:00      33.0         1.096889      143.0
# 2024-12-24 00:00:00-05:00      34.0         1.099129      143.0
# 2024-12-26 00:00:00-05:00      34.0         1.105967      144.0
# 2024-12-27 00:00:00-05:00      34.0         1.095895      144.0
# 2024-12-30 00:00:00-05:00      34.0         1.101587      144.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2000-08-30 00:00:00-04:00               NaN         NaN
# 2000-08-31 00:00:00-04:00               NaN         NaN
# 2000-09-01 00:00:00-04:00               NaN         NaN
# 2000-09-05 00:00:00-04:00               NaN         NaN
# 2000-09-06 00:00:00-04:00               NaN         NaN
# ...                                     ...         ...
# 2024-12-23 00:00:00-05:00          1.319549       536.0
# 2024-12-24 00:00:00-05:00          1.322987       536.0
# 2024-12-26 00:00:00-05:00          1.332018       536.0
# 2024-12-27 00:00:00-05:00          1.320642       536.0
# 2024-12-30 00:00:00-05:00          1.328282       536.0
#
# [6105 rows x 17 columns]

# %%
gold = gold.dropna()

# %%
gold
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2004-09-07 00:00:00-04:00   398.000000   398.000000   398.000000   397.399994
# 2004-09-08 00:00:00-04:00   396.799988   396.799988   396.799988   399.399994
# 2004-09-09 00:00:00-04:00   398.899994   398.899994   398.899994   398.500000
# 2004-09-10 00:00:00-04:00   401.000000   402.000000   401.000000   401.899994
# 2004-09-13 00:00:00-04:00   404.100006   404.100006   404.100006   404.100006
# ...                                ...          ...          ...          ...
# 2024-12-20 00:00:00-05:00  2605.300049  2631.600098  2604.899902  2628.699951
# 2024-12-23 00:00:00-05:00  2620.000000  2627.699951  2611.100098  2612.300049
# 2024-12-24 00:00:00-05:00  2613.000000  2620.000000  2609.500000  2620.000000
# 2024-12-26 00:00:00-05:00  2628.500000  2638.800049  2627.899902  2638.800049
# 2024-12-27 00:00:00-05:00  2617.699951  2617.699951  2616.399902  2617.199951
#
#                            Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 2004-09-07 00:00:00-04:00      60   399.399994       1       0.996115
# 2004-09-08 00:00:00-04:00      20   398.500000       0       1.002510
# 2004-09-09 00:00:00-04:00      20   401.899994       1       0.998872
# 2004-09-10 00:00:00-04:00     120   404.100006       1       1.004248
# 2004-09-13 00:00:00-04:00     120   405.700012       1       1.002730
# ...                           ...          ...     ...            ...
# 2024-12-20 00:00:00-05:00     592  2612.300049       0       1.006991
# 2024-12-23 00:00:00-05:00     451  2620.000000       1       0.996871
# 2024-12-24 00:00:00-05:00      35  2638.800049       1       1.001472
# 2024-12-26 00:00:00-05:00      84  2617.199951       0       1.003575
# 2024-12-27 00:00:00-05:00      84  2633.300049       1       0.995890
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2004-09-07 00:00:00-04:00      0.0       0.982156      1.0        0.996152
# 2004-09-08 00:00:00-04:00      1.0       0.992495      1.0        1.000505
# 2004-09-09 00:00:00-04:00      1.0       0.995354      1.0        0.997817
# 2004-09-10 00:00:00-04:00      1.0       1.005907      2.0        1.005605
# 2004-09-13 00:00:00-04:00      2.0       1.009594      3.0        1.010469
# ...                            ...            ...      ...             ...
# 2024-12-20 00:00:00-05:00      1.0       0.999263      1.0        0.986298
# 2024-12-23 00:00:00-05:00      1.0       0.995989      1.0        0.980341
# 2024-12-24 00:00:00-05:00      1.0       1.000787      2.0        0.983330
# 2024-12-26 00:00:00-05:00      2.0       1.007791      3.0        0.990562
# 2024-12-27 00:00:00-05:00      1.0       0.997637      3.0        0.982638
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2004-09-07 00:00:00-04:00      28.0         1.000446      129.0
# 2004-09-08 00:00:00-04:00      29.0         1.005260      129.0
# 2004-09-09 00:00:00-04:00      28.0         1.002759      129.0
# 2004-09-10 00:00:00-04:00      29.0         1.011109      129.0
# 2004-09-13 00:00:00-04:00      29.0         1.016397      130.0
# ...                             ...              ...        ...
# 2024-12-20 00:00:00-05:00      33.0         1.104803      144.0
# 2024-12-23 00:00:00-05:00      33.0         1.096889      143.0
# 2024-12-24 00:00:00-05:00      34.0         1.099129      143.0
# 2024-12-26 00:00:00-05:00      34.0         1.105967      144.0
# 2024-12-27 00:00:00-05:00      34.0         1.095895      144.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2004-09-07 00:00:00-04:00          1.218768       513.0
# 2004-09-08 00:00:00-04:00          1.224446       513.0
# 2004-09-09 00:00:00-04:00          1.221232       513.0
# 2004-09-10 00:00:00-04:00          1.231176       514.0
# 2004-09-13 00:00:00-04:00          1.237423       515.0
# ...                                     ...         ...
# 2024-12-20 00:00:00-05:00          1.328315       537.0
# 2024-12-23 00:00:00-05:00          1.319549       536.0
# 2024-12-24 00:00:00-05:00          1.322987       536.0
# 2024-12-26 00:00:00-05:00          1.332018       536.0
# 2024-12-27 00:00:00-05:00          1.320642       536.0
#
# [5104 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= 0.6] = 1
    preds[preds < 0.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(gold, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    2262
# 1.0     342
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5292397660818714
